# %%
import numpy as np
import matplotlib.pyplot as plt

l, T = 2.0, 0.5
a2, nu = 0.1, 1.0
N, M = 200, 200
R = 10.0

max_iters = 1000


h, tau = l / N, T / M
s = np.linspace(0, l, N + 1)
phi = np.zeros_like(s)
y_target = np.cos(np.pi * s / l)


plt.figure(figsize=(18, 6))
plt.subplot(1, 2, 1)
plt.plot(s, y_target, label="func", color="fuchsia")
plt.legend()
plt.grid()
